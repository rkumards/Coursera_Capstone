# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ### Steps

# %% [markdown]
# Gather data from different source using web scraping
# Analysis data by viewing and remove useless columns
# Removing null and NA values from dataset
# Renaming Columns name if required
# Calculate parameter like per capita income, population density etc.
# Compare two city and choose the best one
# Gather foursquare.com data to get near by palaces
# Find if Indian restaurant are present near to famous places
# Check rating of these restaurant

# %% [markdown]
# # getting data from differnt source

# %% [markdown]
# We have taken data from two diiferent  source "https://en.wikipedia.org/wiki/New_York_City#Demographics" and "https://en.wikipedia.org/wiki/New_York_City#Race_and_ethnicity" for nework city data and

# %% [markdown]
# https://en.wikipedia.org/wiki/Toronto and https://en.wikipedia.org/wiki/Demographics_of_Toronto

# %% [markdown]
# #Reading Data newyork data

# %%
# importing libraries
import pandas as pd
import numpy as np
import xlrd
ny_data=pd.read_excel("C:/Users/r/Desktop/projects/Coursera_Capstone/nydata.xlsx", Sheet="Sheet1");
ny_data.head()
# Out:
#          Borough  Population  GDP in billions  GDP per capita  \
# 0      The Bronx     1432132           42.695           29200
# 1       Brooklyn     2582830           91.559           34600
# 2      Manhattan     1628701          600.244          360900
# 3         Queens     2278906           93.310           39600
# 4  Staten Island      476179           14.514           30300
#
#    land area in miles  land area in sq km  Density psercon per sq. mi  \
# 0               42.10              109.04                       34653
# 1               70.82              183.42                       37137
# 2               22.83               59.13                       72033
# 3              108.53              281.09                       21460
# 4               58.37              151.18                        8112
#
#    Density person per sq-km  Indian Americans  \
# 0                     13231             16748
# 1                     14649             25270
# ...

# %%
#readining toronto dataset
toro_data=pd.read_excel("C:/Users/r/Desktop/projects/Coursera_Capstone/toronto_population.xlsx", Sheet="Sheet1")
toto_borough=pd.read_excel("C:/Users/r/Desktop/projects/Coursera_Capstone/Borough_toronto.xlsx", Sheet="Sheet1")
toro_data
# Out:
#                      Etheticity  Population (2016)  \
# 0                      Europian            1282750
# 1                   South Asian             338965
# 2                       Chinese             299460
# 3                         Black             239850
# 4                      Filipino             152715
# 5                Latin American              77160
# 6                          Arab              36030
# 7               Southeast Asian              41645
# 8                    West Asian              60325
# 9                        Korean              41640
# 10                     Japanese              13410
# 11     Visible minority, n.i.e.              36975
# 12  Multiple visible minorities              47675
#
#     % of total population (2016)  Population (2011)  \
# 0                          0.477            1292365
# 1                          0.126             317100
# 2                          0.111             278390
# ...

# %%
toto_borough
# Out:
#            Borough Name  Total area sq km  Population  Density per sq-km
# 0               Ontario        1076395.00    13448494               14.6
# 1       City of Toronto            630.00     2731571             4149.5
# 2                Durham           2523.15      645862              241.0
# 3                  Peel           1241.99     1381739             1040.0
# 4                  York           1761.84     1109909              585.9
# 5                Halton            967.17      548435              520.4
# 6  Greater Toronto Area           7124.15     6417516              850.0

# %% [markdown]
# Data that we haverecived from differnt sources are in different form, Darta cleanising was required , Some the columns are droped and some useful columns are kept.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Ploating borough wise population Plot of both cities

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
x=ny_data['Borough']
y=ny_data['Density person per sq-km']
ax.set_title('Indian Amaericans population different borough of Newyork City')
ax.set_xlabel('Borough')
ax.set_ylabel('Population density per sq-km')

ax.bar(x,y)
plt.show()

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
x=toto_borough['Borough Name']
y=toto_borough['Density per sq-km']
ax.set_title(' population different borough of Toronto City')
ax.set_xlabel('Borough')
ax.set_ylabel('Population density per sq-km')
ax.bar(x,y)
plt.show()

# %%
total_pop=np.sum(ny_data['Population'])
total_indian=np.sum(ny_data['Indian Americans'])
total_area=np.sum(ny_data['land area in sq km'])
avg_gdp=np.mean(ny_data['GDP per capita'])

print('Total popultion in NY city is ', total_pop)
print('Total Indian in NY city is ', total_indian)
print('Total Area of NY city is ', total_area)
print('Avg GDP per Capita of NY city is ', avg_gdp)
# Out:
# Total popultion in NY city is  16797496
# Total Indian in NY city is  445913
# Total Area of NY city is  1567.69
# Avg GDP per Capita of NY city is  98716.6666667

# %%
total_pop2=np.sum(toto_borough['Population'])
total_indian2=toro_data.loc[1,'Population (2016)']
total_area2=np.sum(toto_borough['Total area sq km'])
avg_gdp2=42279.90
print('Total popultion in Toronto city is ', total_pop2)
print('Total Indian in Toronto city is ', total_indian2)
print('Total Area of Toronto city is ', total_area2)
print('Avg GDP per Capita of NY city is ', avg_gdp2)
# Out:
# Total popultion in Toronto city is  26283526
# Total Indian in Toronto city is  338965
# Total Area of Toronto city is  1090643.3
# Avg GDP per Capita of NY city is  42279.9

# %%
fig, (ax1, ax2)=plt.subplots(1,2)
#ax1=fig.add_axes([0,0,1,1])
#ax2=fig.add_axes([0,0,1,1])

x=['New York', 'Toronto']
y1=[total_indian/total_area, total_indian2/total_area2]
y2=[avg_gdp, avg_gdp2]
fig.suptitle(' Comparison between New York and Toronto City')
ax1.set_xlabel('City')

ax2.set_xlabel('City')
#ax.set_ylabel('Population density per sq-km')
ax1.bar(x,y1)
ax2.bar(x,y2)

plt.show()

# %% [markdown]
# By looking above figures we identfed that New york high density area then Toronto, and also the GDP per capita of New York is heigher than the Toronto city. Hence it will be advised to start business in New York

# %% [markdown]
# Now using foursquare.com we identify the famous place in New York City

# %%
# new york city longitude and latitude
#lat=40.7128
#long=-74.006
lat=40.7829
long=-73.9654

# %%
import requests # library to handle requests
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium # plotting library

# %%
# displaying Manhttan as it is most poulalus part in NY
# we chose central park as famous placein Manhattan
m=folium.Map(location=[lat ,long],zoom_start=14)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# getting coordinate of Central park Manhattan New York
address = 'Central Park Manhattan, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7827725 -73.9653627406542

# %% [markdown]
# # Now we will foursquare data to get venues

# %%
#defining client details
import request
CLIENT_ID="CBG2HSUJTJ20OTVXTYQ1GP1TMIZRD4SYAGGKSVQCDKCRRM0Y"
CLIENT_SECRET="MVQGQINNDSD13VT4UKOULONXFPO32QV34ZYDCI3Q3WSAQB2O"
query='indian'
radius=5000
version='20180604'
LIMIT=30

# %%
#defining url for venues
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, version, query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CBG2HSUJTJ20OTVXTYQ1GP1TMIZRD4SYAGGKSVQCDKCRRM0Y&client_secret=MVQGQINNDSD13VT4UKOULONXFPO32QV34ZYDCI3Q3WSAQB2O&ll=40.7827725,-73.9653627406542&v=20180604&query=indian&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e89a87a1835dd001b250ddc'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '56ed855a498ef3bb022352c3',
#     'location': {'address': '1724 2nd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '89th & 90th St',
#      'distance': 1318,
#      'formattedAddress': ['1724 2nd Ave (89th & 90th St)',
#       'New York, NY 10128',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78020580283837,
#        'lng': -73.95008785684102}],
#      'lat': 40.78020580283837,
#      'lng': -73.95008785684102,
#      'postalCode': '10128',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 1  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 2  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 3  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 4  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                  name         categories             address  \
# 0              Mughlai Indian Cuisine  Indian Restaurant        1724 2nd Ave
# 1     Deep Indian Kitchen (IndiKitch)  Indian Restaurant         940 8th Ave
# 2  2 Darbar Grill Fine Indian Cuisine  Indian Restaurant       157 E 55th St
# 3               Indian fast food cart         Food Truck         53rd street
# 4                Raj's Indian Kitchen  Indian Restaurant  27-18 Queens Plz S
#
#    cc              city        country                      crossStreet  \
# 0  US          New York  United States                   89th & 90th St
# 1  US          New York  United States  between W 56th St and W 57th St
# 2  US          New York  United States        btwn Lexington & 3rd Ave.
# 3  US          New York  United States                      Park avenue
# 4  US  Long Island City  United States                              NaN
#
#    distance                                   formattedAddress  \
# ...

# %%
# instantiate a feature group for the incidents in the datafram

#import folium as fol;

map_venues = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(dataframe_filtered.lat, dataframe_filtered.lng):
    map_venues.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(dataframe_filtered.lat)
longitudes = list(dataframe_filtered.lng)
labels = list(dataframe_filtered.name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(m)    
    
# add incidents to map
m.add_child(map_venues)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#pick one of the venue
venue_name=dataframe_filtered.name[0]
venue_id=dataframe_filtered.id[0]
print('Venue ID is',venue_id)
# Out:
# Venue ID is 56ed855a498ef3bb022352c3

# %%
#checking rating of 
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#latitude and longitude of brooklyn
lat2=40.7061
long2=-73.9969
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat2, long2, version, query, radius, LIMIT)
results2 = requests.get(url).json()
# assign relevant part of JSON to venues
venues2 = results2['response']['venues']

# tranform venues into a dataframe
dataframe2 = json_normalize(venues2)
dataframe2.head()
filtered_columns = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('location.')] + ['id']
brooklyn_filtered = dataframe2.loc[:, filtered_columns]

# filter the category for each row
brooklyn_filtered['categories'] = brooklyn_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
brooklyn_filtered.columns = [column.split('.')[-1] for column in brooklyn_filtered.columns]

# %%
#neighbourhood 1 : Manhattan
dataframe_filtered.describe()
# Out:
#           distance        lat        lng
# count    30.000000  30.000000  30.000000
# mean   2717.766667  40.768716 -73.967621
# std    1255.331298   0.017638   0.019830
# min     994.000000  40.742025 -73.996796
# 25%    1652.000000  40.759208 -73.982445
# 50%    2581.500000  40.765362 -73.973040
# 75%    3107.500000  40.774831 -73.955103
# max    5713.000000  40.823200 -73.920462

# %% [markdown]
# This giving the description like total no of restaurant with limit in this case 30nos, mean distance it of all restaurants is 1.9 km approx. std div 1.2 km means  there quite distance between two Indian restaurants. And 22 out of 30 resaturants lies near to ceneral park

# %%
#neighbourhood 1 : Manhattan
brooklyn_filtered.describe()
# Out:
#           distance        lat        lng
# count    30.000000  30.000000  30.000000
# mean   1938.800000  40.711633 -74.000401
# std    1238.753445   0.015518   0.016583
# min     828.000000  40.685965 -74.035902
# 25%    1232.500000  40.703646 -74.010910
# 50%    1389.000000  40.711121 -74.007842
# 75%    2142.250000  40.715619 -73.992372
# max    5653.000000  40.753725 -73.951320

# %%
#venue_id = '3fd66200f964a520f4e41ee3' # ID of Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, version)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %% [markdown]
# We found that the popularity of indian restaurant can be mesured as no. of restaurants with 3km radius. Stakeholder either select high dense city or middle dense city eg. Newyork and Brooklyn. Lets select Manhattan.

# %%
result['response']['venue']['tips']['count']
# Out:
# 9

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, version, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e88b735c94979001bbad645'},
#  'response': {'tips': {'count': 9,
#    'items': [{'agreeCount': 1,
#      'canonicalUrl': 'https://foursquare.com/item/57769a56498ed8a2ceb8afd0',
#      'createdAt': 1467390550,
#      'disagreeCount': 0,
#      'id': '57769a56498ed8a2ceb8afd0',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'photo': {'createdAt': 1467390595,
#       'height': 2988,
#       'id': '57769a83498ebddf8ae25948',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'suffix': '/138487783_yV5hTNYh4KeBgL-0jEDTy2K_CbRCjgfCZ_vRs6pfk7k.jpg',
#       'visibility': 'public',
#       'width': 5312},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/138487783_yV5hTNYh4KeBgL-0jEDTy2K_CbRCjgfCZ_vRs6pfk7k.jpg',
# ...

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['createdAt', 'todo', 'logView', 'disagreeCount', 'photo', 'type', 'user', 'canonicalUrl', 'likes', 'agreeCount', 'lang', 'text', 'id', 'photourl'])

# %%
    pd.set_option('display.max_colwidth', -1)

    tips_df = json_normalize(tips) # json normalize tips

    # columns to keep
    filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
    tips_filtered = tips_df.loc[:, filtered_columns]

    # display tips
    tips_filtered
# Out:
# c:\users\r\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                                                                                               text  \
# 0  I wish i could remember the name of this but its the first option on the back page. Best thing I've eaten since working in this part of the city. Highly recommended. And half price for lunch!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  1           0              57769a56498ed8a2ceb8afd0  Taylor
#
#   user.lastName  user.gender    user.id
# ...

# %%
user_id = '138487783' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, version) # define URL

# send GET request
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 401,
#   'errorDetail': 'Missing oauth_token. See https://developer.foursquare.com/docs/api/configuration/authentication for details.',
#   'errorType': 'invalid_auth',
#   'requestId': '5e88b7fc14a126001b4cd7f7'},
#  'response': {}}

# %%
user_data['tips']

# %%
# get users tip

# %%
Purpose of this project was to identify an area of opening new Indian restaurant which is closer to centre with in order to search optimal location. By calculating restaurant density distribution from Foursquare data we have first identified general boroughs. Final decision on optimal restaurant location will be made by stakeholders based on specific characteristics of neighbourhoods and locations in every recommended zone. 
So far the recommendation is given based population density, per captia income, restaurant density and community in that area. In future selection may based on air quality , road and other environment factors.
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, version, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                                                text  \
# 0   They serve coffee!!!!!!
# 1   The linguine with clams is on point 👌
# 2   Quick, cheap lunch that tastes good! Way shorter line than Chipotle, too.
# 3   You’re not a real New Yorker until you’ve shame-ordered Insomnia Cookies for delivery at 3am
# 4   Good for you yet still tasty! Clean green protein is my go-to after I hit the gym 💪
# 5   Burger game strong 💪
# 6   Great burgers & fries! Also, this place is exactly what it’s like when you go to a bar in the Southwest. Source: I’m from Arizona.
# 7   Açaí bowl + peanut butter + whey protein = 💪💪💪
# 8   Highly underrated and way less crowded than Central Park!
# ...

# %% [markdown]
# This show pepople in manhatton likes Indian resaurants and multiple Indian resaurants within 3km radius shows there is appotunity to open new branch her chances of surviving here is more.

# %% [markdown]
# # Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify an area of opening new Indian restaurant which is closer to centre with in order to search optimal location. By calculating restaurant density distribution from Foursquare data we have first identified general boroughs. Final decision on optimal restaurant location will be made by stakeholders based on specific characteristics of neighbourhoods and locations in every recommended zone.
# So far the recommendation is given based population density, per captia income, restaurant density and community in that area. In future selection may based on air quality , road and other environment factors.
